# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 606

# %%
# import the datetime module from the datetime library.
from datetime import datetime
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a3403f62cded105762a7d79768a5a187

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval    ")
print("----------------------------")

# Create counter.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        try:
            city_snow = city_weather["snow"]["1h"]
        except KeyError: 
            city_snow = 0 
        try:
            city_rain = city_weather["rain"]["1h"]
        except KeyError: 
            city_rain = 0
        city_weatherD = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Snow": city_snow,
                          "Rain": city_rain,
                          "Weather Description":city_weatherD})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | karkaralinsk
# City not found. Skipping...
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | nacozari
# Processing Record 4 of Set 1 | soyo
# Processing Record 5 of Set 1 | qaanaaq
# Processing Record 6 of Set 1 | tunduru
# City not found. Skipping...
# Processing Record 7 of Set 1 | mercedes
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | port blair
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | norman wells
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | hasaki
# Processing Record 16 of Set 1 | makakilo city
# Processing Record 17 of Set 1 | tripoli
# Processing Record 18 of Set 1 | saskylakh
# Processing Record 19 of Set 1 | bredasdorp
# Processing Record 20 of Set 1 | auki
# Processing Record 21 of Set 1 | port hedland
# Processing Record 22 of Set 1 | butaritari
# Processing Record 23 of Set 1 | helong
# Processing Record 24 of Set 1 | lagoa
# Processing Record 25 of Set 1 | skalistyy
# City not found. Skipping...
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | angola
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | barrow
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | cabo san lucas
# Processing Record 32 of Set 1 | orbetello
# Processing Record 33 of Set 1 | vila velha
# Processing Record 34 of Set 1 | mahebourg
# Processing Record 35 of Set 1 | alofi
# Processing Record 36 of Set 1 | shkotovo-22
# City not found. Skipping...
# Processing Record 37 of Set 1 | castro
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | nikolskoye
# Processing Record 40 of Set 1 | lebu
# Processing Record 41 of Set 1 | saint-philippe
# Processing Record 42 of Set 1 | miranorte
# City not found. Skipping...
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | cherskiy
# Processing Record 45 of Set 1 | labuhan
# Processing Record 46 of Set 1 | tilichiki
# Processing Record 47 of Set 1 | haines junction
# Processing Record 48 of Set 1 | ninghai
# Processing Record 49 of Set 1 | erenhot
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | hobyo
# Processing Record 2 of Set 2 | busselton
# Processing Record 3 of Set 2 | cape town
# Processing Record 4 of Set 2 | bandarbeyla
# Processing Record 5 of Set 2 | torbay
# Processing Record 6 of Set 2 | mar del plata
# Processing Record 7 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 2 | mizpe ramon
# City not found. Skipping...
# Processing Record 9 of Set 2 | kurumkan
# Processing Record 10 of Set 2 | umarkot
# Processing Record 11 of Set 2 | acajutla
# Processing Record 12 of Set 2 | surgut
# Processing Record 13 of Set 2 | upernavik
# Processing Record 14 of Set 2 | waltershausen
# Processing Record 15 of Set 2 | crato
# Processing Record 16 of Set 2 | bengkulu
# Processing Record 17 of Set 2 | kapaa
# Processing Record 18 of Set 2 | andra
# Processing Record 19 of Set 2 | kununurra
# Processing Record 20 of Set 2 | tanggu
# Processing Record 21 of Set 2 | sao joao da barra
# Processing Record 22 of Set 2 | port-gentil
# Processing Record 23 of Set 2 | tiznit
# Processing Record 24 of Set 2 | qaqortoq
# Processing Record 25 of Set 2 | hofn
# Processing Record 26 of Set 2 | poronaysk
# Processing Record 27 of Set 2 | lorengau
# Processing Record 28 of Set 2 | hilo
# Processing Record 29 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 30 of Set 2 | ziro
# Processing Record 31 of Set 2 | jiayuguan
# Processing Record 32 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 2 | bawku
# Processing Record 34 of Set 2 | yumen
# Processing Record 35 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 2 | jamestown
# Processing Record 37 of Set 2 | datong
# Processing Record 38 of Set 2 | rimouski
# Processing Record 39 of Set 2 | dikson
# Processing Record 40 of Set 2 | tessalit
# Processing Record 41 of Set 2 | souillac
# Processing Record 42 of Set 2 | fortuna
# Processing Record 43 of Set 2 | kodiak
# Processing Record 44 of Set 2 | naze
# Processing Record 45 of Set 2 | roma
# Processing Record 46 of Set 2 | cidreira
# Processing Record 47 of Set 2 | new norfolk
# Processing Record 48 of Set 2 | uribia
# Processing Record 49 of Set 2 | yellowknife
# Processing Record 50 of Set 2 | masterton
# Processing Record 1 of Set 3 | virginia beach
# Processing Record 2 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 3 of Set 3 | ribeira grande
# Processing Record 4 of Set 3 | thompson
# Processing Record 5 of Set 3 | cam pha
# City not found. Skipping...
# Processing Record 6 of Set 3 | omboue
# Processing Record 7 of Set 3 | hernani
# Processing Record 8 of Set 3 | arlit
# Processing Record 9 of Set 3 | chokurdakh
# Processing Record 10 of Set 3 | vostok
# Processing Record 11 of Set 3 | hartselle
# Processing Record 12 of Set 3 | sal rei
# Processing Record 13 of Set 3 | wilmington
# Processing Record 14 of Set 3 | pevek
# Processing Record 15 of Set 3 | husavik
# Processing Record 16 of Set 3 | vao
# Processing Record 17 of Set 3 | vanavara
# Processing Record 18 of Set 3 | sarangani
# Processing Record 19 of Set 3 | slave lake
# Processing Record 20 of Set 3 | geraldton
# Processing Record 21 of Set 3 | sur
# Processing Record 22 of Set 3 | jiangyou
# Processing Record 23 of Set 3 | hobart
# Processing Record 24 of Set 3 | kungurtug
# Processing Record 25 of Set 3 | igrim
# Processing Record 26 of Set 3 | huarmey
# Processing Record 27 of Set 3 | demba
# Processing Record 28 of Set 3 | berlevag
# Processing Record 29 of Set 3 | margate
# Processing Record 30 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 3 | tiksi
# Processing Record 32 of Set 3 | egvekinot
# Processing Record 33 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 3 | buariki
# City not found. Skipping...
# Processing Record 35 of Set 3 | rawson
# Processing Record 36 of Set 3 | provideniya
# Processing Record 37 of Set 3 | manakara
# Processing Record 38 of Set 3 | antofagasta
# Processing Record 39 of Set 3 | baykit
# Processing Record 40 of Set 3 | oneida
# Processing Record 41 of Set 3 | havre-saint-pierre
# Processing Record 42 of Set 3 | rassvet
# Processing Record 43 of Set 3 | anadyr
# Processing Record 44 of Set 3 | khatanga
# Processing Record 45 of Set 3 | mareeba
# Processing Record 46 of Set 3 | gizo
# Processing Record 47 of Set 3 | kenai
# Processing Record 48 of Set 3 | yulara
# Processing Record 49 of Set 3 | kahului
# Processing Record 50 of Set 3 | arraial do cabo
# Processing Record 1 of Set 4 | cabedelo
# Processing Record 2 of Set 4 | port elizabeth
# Processing Record 3 of Set 4 | norsup
# Processing Record 4 of Set 4 | north bay
# Processing Record 5 of Set 4 | bethel
# Processing Record 6 of Set 4 | wajima
# Processing Record 7 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 4 | kilindoni
# Processing Record 9 of Set 4 | tuatapere
# Processing Record 10 of Set 4 | zabid
# Processing Record 11 of Set 4 | pangnirtung
# Processing Record 12 of Set 4 | oksfjord
# Processing Record 13 of Set 4 | hualmay
# Processing Record 14 of Set 4 | cap malheureux
# Processing Record 15 of Set 4 | aykhal
# Processing Record 16 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 17 of Set 4 | grand gaube
# Processing Record 18 of Set 4 | tomatlan
# Processing Record 19 of Set 4 | mehamn
# Processing Record 20 of Set 4 | phnum penh
# City not found. Skipping...
# Processing Record 21 of Set 4 | sinnamary
# Processing Record 22 of Set 4 | kaeo
# Processing Record 23 of Set 4 | severo-kurilsk
# Processing Record 24 of Set 4 | codrington
# Processing Record 25 of Set 4 | tromso
# Processing Record 26 of Set 4 | zeya
# Processing Record 27 of Set 4 | gilleleje
# Processing Record 28 of Set 4 | wolsztyn
# Processing Record 29 of Set 4 | nome
# Processing Record 30 of Set 4 | kamenka
# Processing Record 31 of Set 4 | karratha
# Processing Record 32 of Set 4 | hambantota
# Processing Record 33 of Set 4 | atuona
# Processing Record 34 of Set 4 | mahajanga
# Processing Record 35 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 4 | komsomolskiy
# Processing Record 37 of Set 4 | oranjemund
# Processing Record 38 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 4 | straseni
# Processing Record 40 of Set 4 | road town
# Processing Record 41 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 4 | porto novo
# Processing Record 43 of Set 4 | challapata
# Processing Record 44 of Set 4 | tasiilaq
# Processing Record 45 of Set 4 | kailua
# Processing Record 46 of Set 4 | whyalla
# Processing Record 47 of Set 4 | faanui
# Processing Record 48 of Set 4 | yerbogachen
# Processing Record 49 of Set 4 | seymchan
# Processing Record 50 of Set 4 | douglas
# Processing Record 1 of Set 5 | eldikan
# City not found. Skipping...
# Processing Record 2 of Set 5 | comodoro rivadavia
# Processing Record 3 of Set 5 | santa cruz
# Processing Record 4 of Set 5 | talnakh
# Processing Record 5 of Set 5 | guerrero negro
# Processing Record 6 of Set 5 | kaitangata
# Processing Record 7 of Set 5 | salalah
# Processing Record 8 of Set 5 | clyde river
# Processing Record 9 of Set 5 | fukue
# Processing Record 10 of Set 5 | henties bay
# Processing Record 11 of Set 5 | juneau
# Processing Record 12 of Set 5 | ubinskoye
# Processing Record 13 of Set 5 | georgetown
# Processing Record 14 of Set 5 | pailon
# Processing Record 15 of Set 5 | carnarvon
# Processing Record 16 of Set 5 | tuktoyaktuk
# Processing Record 17 of Set 5 | kobyzhcha
# Processing Record 18 of Set 5 | shcholkine
# City not found. Skipping...
# Processing Record 19 of Set 5 | nadym
# Processing Record 20 of Set 5 | tam ky
# Processing Record 21 of Set 5 | zaanstad
# Processing Record 22 of Set 5 | san patricio
# Processing Record 23 of Set 5 | rapar
# Processing Record 24 of Set 5 | saint-augustin
# Processing Record 25 of Set 5 | keffi
# Processing Record 26 of Set 5 | tual
# Processing Record 27 of Set 5 | yenagoa
# Processing Record 28 of Set 5 | wrexham
# Processing Record 29 of Set 5 | sabha
# Processing Record 30 of Set 5 | tautira
# Processing Record 31 of Set 5 | warri
# Processing Record 32 of Set 5 | cochrane
# Processing Record 33 of Set 5 | coquimbo
# Processing Record 34 of Set 5 | broken hill
# Processing Record 35 of Set 5 | khormuj
# City not found. Skipping...
# Processing Record 36 of Set 5 | macon
# Processing Record 37 of Set 5 | salta
# Processing Record 38 of Set 5 | east london
# Processing Record 39 of Set 5 | alcaniz
# Processing Record 40 of Set 5 | neepawa
# Processing Record 41 of Set 5 | airai
# Processing Record 42 of Set 5 | padang
# Processing Record 43 of Set 5 | ilhabela
# Processing Record 44 of Set 5 | bokoro
# Processing Record 45 of Set 5 | muros
# Processing Record 46 of Set 5 | touros
# Processing Record 47 of Set 5 | mao
# Processing Record 48 of Set 5 | khawhai
# Processing Record 49 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 5 | calabozo
# Processing Record 1 of Set 6 | puerto del rosario
# Processing Record 2 of Set 6 | flinders
# Processing Record 3 of Set 6 | shiyan
# Processing Record 4 of Set 6 | haicheng
# Processing Record 5 of Set 6 | abay
# Processing Record 6 of Set 6 | lompoc
# Processing Record 7 of Set 6 | ballarat
# Processing Record 8 of Set 6 | mount gambier
# Processing Record 9 of Set 6 | hermiston
# Processing Record 10 of Set 6 | do gonbadan
# Processing Record 11 of Set 6 | gornyy
# Processing Record 12 of Set 6 | huambo
# Processing Record 13 of Set 6 | bakchar
# Processing Record 14 of Set 6 | atar
# Processing Record 15 of Set 6 | hetauda
# Processing Record 16 of Set 6 | vuktyl
# Processing Record 17 of Set 6 | tahta
# Processing Record 18 of Set 6 | falam
# Processing Record 19 of Set 6 | ikalamavony
# Processing Record 20 of Set 6 | lazaro cardenas
# Processing Record 21 of Set 6 | waipawa
# Processing Record 22 of Set 6 | buala
# Processing Record 23 of Set 6 | tevaitoa
# Processing Record 24 of Set 6 | black river
# Processing Record 25 of Set 6 | paamiut
# Processing Record 26 of Set 6 | mersing
# Processing Record 27 of Set 6 | narsaq
# Processing Record 28 of Set 6 | lae
# Processing Record 29 of Set 6 | praia da vitoria
# Processing Record 30 of Set 6 | victoria
# Processing Record 31 of Set 6 | vestmannaeyjar
# Processing Record 32 of Set 6 | kruisfontein
# Processing Record 33 of Set 6 | luderitz
# Processing Record 34 of Set 6 | maceio
# Processing Record 35 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 6 | paita
# Processing Record 37 of Set 6 | ust-nera
# Processing Record 38 of Set 6 | monywa
# Processing Record 39 of Set 6 | kavieng
# Processing Record 40 of Set 6 | sisimiut
# Processing Record 41 of Set 6 | deputatskiy
# Processing Record 42 of Set 6 | vila
# Processing Record 43 of Set 6 | aklavik
# Processing Record 44 of Set 6 | roald
# Processing Record 45 of Set 6 | suifenhe
# Processing Record 46 of Set 6 | carbondale
# Processing Record 47 of Set 6 | amahai
# Processing Record 48 of Set 6 | eniwa
# Processing Record 49 of Set 6 | ardistan
# City not found. Skipping...
# Processing Record 50 of Set 6 | kingston
# Processing Record 1 of Set 7 | pangody
# Processing Record 2 of Set 7 | rangapara
# Processing Record 3 of Set 7 | eminabad
# Processing Record 4 of Set 7 | ust-tsilma
# Processing Record 5 of Set 7 | port lincoln
# Processing Record 6 of Set 7 | acapulco
# Processing Record 7 of Set 7 | kashin
# Processing Record 8 of Set 7 | gilgit
# Processing Record 9 of Set 7 | hamilton
# Processing Record 10 of Set 7 | sao filipe
# Processing Record 11 of Set 7 | ilulissat
# Processing Record 12 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 13 of Set 7 | novikovo
# Processing Record 14 of Set 7 | kidal
# Processing Record 15 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 7 | jumla
# Processing Record 17 of Set 7 | camana
# Processing Record 18 of Set 7 | killam
# Processing Record 19 of Set 7 | ponta do sol
# Processing Record 20 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 7 | bud
# Processing Record 22 of Set 7 | hayden
# Processing Record 23 of Set 7 | bilibino
# Processing Record 24 of Set 7 | hithadhoo
# Processing Record 25 of Set 7 | kholmogory
# Processing Record 26 of Set 7 | nivala
# Processing Record 27 of Set 7 | sibolga
# Processing Record 28 of Set 7 | teguldet
# Processing Record 29 of Set 7 | moerai
# Processing Record 30 of Set 7 | te anau
# Processing Record 31 of Set 7 | kendari
# Processing Record 32 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 33 of Set 7 | upington
# Processing Record 34 of Set 7 | bulgan
# Processing Record 35 of Set 7 | malanje
# Processing Record 36 of Set 7 | leningradskiy
# Processing Record 37 of Set 7 | nicoya
# Processing Record 38 of Set 7 | buckeye
# Processing Record 39 of Set 7 | saint george
# Processing Record 40 of Set 7 | raga
# Processing Record 41 of Set 7 | pomabamba
# Processing Record 42 of Set 7 | constitucion
# Processing Record 43 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 7 | catanzaro
# Processing Record 45 of Set 7 | trelew
# Processing Record 46 of Set 7 | meadow lake
# Processing Record 47 of Set 7 | penzance
# Processing Record 48 of Set 7 | kushmurun
# Processing Record 49 of Set 7 | conakry
# Processing Record 50 of Set 7 | turukhansk
# Processing Record 1 of Set 8 | monte patria
# Processing Record 2 of Set 8 | flin flon
# Processing Record 3 of Set 8 | isangel
# Processing Record 4 of Set 8 | marawi
# Processing Record 5 of Set 8 | lensk
# Processing Record 6 of Set 8 | broome
# Processing Record 7 of Set 8 | merauke
# Processing Record 8 of Set 8 | nanortalik
# Processing Record 9 of Set 8 | acuna
# City not found. Skipping...
# Processing Record 10 of Set 8 | beyneu
# Processing Record 11 of Set 8 | muhos
# Processing Record 12 of Set 8 | turayf
# Processing Record 13 of Set 8 | zhireken
# Processing Record 14 of Set 8 | guapiacu
# Processing Record 15 of Set 8 | quelimane
# Processing Record 16 of Set 8 | taoudenni
# Processing Record 17 of Set 8 | narrabri
# Processing Record 18 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 19 of Set 8 | colombo
# Processing Record 20 of Set 8 | sorland
# Processing Record 21 of Set 8 | balgazyn
# Processing Record 22 of Set 8 | sosva
# Processing Record 23 of Set 8 | sinjar
# Processing Record 24 of Set 8 | faya
# Processing Record 25 of Set 8 | pacific grove
# Processing Record 26 of Set 8 | toora-khem
# Processing Record 27 of Set 8 | campbell river
# Processing Record 28 of Set 8 | gatehouse of fleet
# Processing Record 29 of Set 8 | sept-iles
# Processing Record 30 of Set 8 | nago
# Processing Record 31 of Set 8 | channel-port aux basques
# Processing Record 32 of Set 8 | west wendover
# Processing Record 33 of Set 8 | kem
# Processing Record 34 of Set 8 | lewistown
# Processing Record 35 of Set 8 | bambous virieux
# Processing Record 36 of Set 8 | neftcala
# Processing Record 37 of Set 8 | werota
# Processing Record 38 of Set 8 | providencia
# Processing Record 39 of Set 8 | santa rosa
# Processing Record 40 of Set 8 | madhogarh
# Processing Record 41 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 8 | araouane
# Processing Record 43 of Set 8 | ixtapa
# Processing Record 44 of Set 8 | vanimo
# Processing Record 45 of Set 8 | biak
# Processing Record 46 of Set 8 | kathu
# Processing Record 47 of Set 8 | tarjan
# Processing Record 48 of Set 8 | sharjah
# Processing Record 49 of Set 8 | uyemskiy
# Processing Record 50 of Set 8 | awbari
# Processing Record 1 of Set 9 | svrljig
# Processing Record 2 of Set 9 | alyangula
# Processing Record 3 of Set 9 | axim
# Processing Record 4 of Set 9 | scottsbluff
# Processing Record 5 of Set 9 | khandyga
# Processing Record 6 of Set 9 | olinda
# Processing Record 7 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 8 of Set 9 | mizoch
# Processing Record 9 of Set 9 | almeirim
# Processing Record 10 of Set 9 | ahipara
# Processing Record 11 of Set 9 | udgir
# Processing Record 12 of Set 9 | isiro
# Processing Record 13 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 9 | monrovia
# Processing Record 15 of Set 9 | baghdad
# Processing Record 16 of Set 9 | klaksvik
# Processing Record 17 of Set 9 | ous
# Processing Record 18 of Set 9 | maumere
# Processing Record 19 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 9 | mongo
# Processing Record 21 of Set 9 | arawa
# Processing Record 22 of Set 9 | nador
# Processing Record 23 of Set 9 | ola
# Processing Record 24 of Set 9 | ambon
# Processing Record 25 of Set 9 | talara
# Processing Record 26 of Set 9 | sao pedro do sul
# Processing Record 27 of Set 9 | aswan
# Processing Record 28 of Set 9 | tarko-sale
# Processing Record 29 of Set 9 | marataizes
# Processing Record 30 of Set 9 | manta
# Processing Record 31 of Set 9 | calatayud
# Processing Record 32 of Set 9 | namatanai
# Processing Record 33 of Set 9 | lishui
# Processing Record 34 of Set 9 | nortelandia
# Processing Record 35 of Set 9 | kavaratti
# Processing Record 36 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 9 | dunedin
# Processing Record 38 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 9 | tankhoy
# Processing Record 40 of Set 9 | los llanos de aridane
# Processing Record 41 of Set 9 | nouadhibou
# Processing Record 42 of Set 9 | courtenay
# Processing Record 43 of Set 9 | longyearbyen
# Processing Record 44 of Set 9 | pisco
# Processing Record 45 of Set 9 | mongomo
# Processing Record 46 of Set 9 | baie-saint-paul
# Processing Record 47 of Set 9 | gat
# Processing Record 48 of Set 9 | yarovoye
# Processing Record 49 of Set 9 | hyeres
# Processing Record 50 of Set 9 | yar-sale
# Processing Record 1 of Set 10 | luebo
# Processing Record 2 of Set 10 | la libertad
# Processing Record 3 of Set 10 | srednekolymsk
# Processing Record 4 of Set 10 | halifax
# Processing Record 5 of Set 10 | samarai
# Processing Record 6 of Set 10 | george
# Processing Record 7 of Set 10 | taltal
# Processing Record 8 of Set 10 | aitape
# Processing Record 9 of Set 10 | lydenburg
# Processing Record 10 of Set 10 | shakawe
# Processing Record 11 of Set 10 | ibra
# Processing Record 12 of Set 10 | san andres
# Processing Record 13 of Set 10 | graaff-reinet
# Processing Record 14 of Set 10 | shingu
# Processing Record 15 of Set 10 | mitsamiouli
# Processing Record 16 of Set 10 | nuuk
# Processing Record 17 of Set 10 | hanzhong
# Processing Record 18 of Set 10 | kaffrine
# Processing Record 19 of Set 10 | luganville
# Processing Record 20 of Set 10 | dzierzoniow
# Processing Record 21 of Set 10 | teknaf
# Processing Record 22 of Set 10 | zhuji
# Processing Record 23 of Set 10 | krasnogorsk
# Processing Record 24 of Set 10 | cartagena
# Processing Record 25 of Set 10 | zhigansk
# Processing Record 26 of Set 10 | bubaque
# Processing Record 27 of Set 10 | hirado
# Processing Record 28 of Set 10 | ormara
# Processing Record 29 of Set 10 | odweyne
# Processing Record 30 of Set 10 | achisay
# City not found. Skipping...
# Processing Record 31 of Set 10 | kutum
# Processing Record 32 of Set 10 | ventersburg
# Processing Record 33 of Set 10 | callaguip
# Processing Record 34 of Set 10 | hami
# Processing Record 35 of Set 10 | vestbygda
# City not found. Skipping...
# Processing Record 36 of Set 10 | astana
# Processing Record 37 of Set 10 | lavrentiya
# Processing Record 38 of Set 10 | lasa
# Processing Record 39 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 10 | natal
# Processing Record 41 of Set 10 | kraskino
# Processing Record 42 of Set 10 | avera
# Processing Record 43 of Set 10 | cayenne
# Processing Record 44 of Set 10 | les cayes
# Processing Record 45 of Set 10 | longkou
# Processing Record 46 of Set 10 | ipira
# Processing Record 47 of Set 10 | abu kamal
# Processing Record 48 of Set 10 | kalabugao
# City not found. Skipping...
# Processing Record 49 of Set 10 | korla
# Processing Record 50 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 1 of Set 11 | khakhea
# Processing Record 2 of Set 11 | riyadh
# Processing Record 3 of Set 11 | dombarovskiy
# Processing Record 4 of Set 11 | walvis bay
# Processing Record 5 of Set 11 | arcachon
# Processing Record 6 of Set 11 | fairview
# Processing Record 7 of Set 11 | popondetta
# Processing Record 8 of Set 11 | dingle
# Processing Record 9 of Set 11 | stornoway
# Processing Record 10 of Set 11 | amboasary
# Processing Record 11 of Set 11 | dabat
# Processing Record 12 of Set 11 | racine
# Processing Record 13 of Set 11 | maputo
# Processing Record 14 of Set 11 | lidkoping
# Processing Record 15 of Set 11 | bay roberts
# Processing Record 16 of Set 11 | palatka
# Processing Record 17 of Set 11 | coahuayana
# Processing Record 18 of Set 11 | palmerston
# Processing Record 19 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 20 of Set 11 | akdepe
# Processing Record 21 of Set 11 | athens
# Processing Record 22 of Set 11 | olds
# Processing Record 23 of Set 11 | mogadishu
# Processing Record 24 of Set 11 | gunjur
# Processing Record 25 of Set 11 | palmer
# Processing Record 26 of Set 11 | marsabit
# Processing Record 27 of Set 11 | skjervoy
# Processing Record 28 of Set 11 | midland
# Processing Record 29 of Set 11 | ketchikan
# Processing Record 30 of Set 11 | chihuahua
# Processing Record 31 of Set 11 | lata
# Processing Record 32 of Set 11 | lubawa
# Processing Record 33 of Set 11 | gasa
# Processing Record 34 of Set 11 | oistins
# Processing Record 35 of Set 11 | kinkala
# Processing Record 36 of Set 11 | greymouth
# Processing Record 37 of Set 11 | ust-maya
# Processing Record 38 of Set 11 | coihaique
# Processing Record 39 of Set 11 | wewak
# Processing Record 40 of Set 11 | akyab
# Processing Record 41 of Set 11 | khani
# Processing Record 42 of Set 11 | barcelos
# Processing Record 43 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 11 | ouadda
# Processing Record 45 of Set 11 | roros
# Processing Record 46 of Set 11 | vestmanna
# Processing Record 47 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 11 | werda
# Processing Record 49 of Set 11 | alice springs
# Processing Record 50 of Set 11 | tchibanga
# Processing Record 1 of Set 12 | pochutla
# Processing Record 2 of Set 12 | vila franca do campo
# Processing Record 3 of Set 12 | pringsewu
# Processing Record 4 of Set 12 | zhezkazgan
# Processing Record 5 of Set 12 | rayagada
# Processing Record 6 of Set 12 | okha
# Processing Record 7 of Set 12 | burns lake
# Processing Record 8 of Set 12 | teahupoo
# Processing Record 9 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 12 | laguna
# Processing Record 11 of Set 12 | prince rupert
# Processing Record 12 of Set 12 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 13 of Set 12 | mpwapwa
# Processing Record 14 of Set 12 | yarada
# Processing Record 15 of Set 12 | doda
# Processing Record 16 of Set 12 | ulladulla
# Processing Record 17 of Set 12 | uhlove
# Processing Record 18 of Set 12 | umm kaddadah
# Processing Record 19 of Set 12 | solnechnyy
# Processing Record 20 of Set 12 | itarema
# Processing Record 21 of Set 12 | port keats
# Processing Record 22 of Set 12 | losinyy
# Processing Record 23 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 24 of Set 12 | port hardy
# Processing Record 25 of Set 12 | mastic beach
# Processing Record 26 of Set 12 | jaisalmer
# Processing Record 27 of Set 12 | kushima
# Processing Record 28 of Set 12 | mohacs
# Processing Record 29 of Set 12 | ventnor city
# Processing Record 30 of Set 12 | abilene
# Processing Record 31 of Set 12 | laem sing
# Processing Record 32 of Set 12 | zhanaozen
# Processing Record 33 of Set 12 | baherden
# Processing Record 34 of Set 12 | harper
# Processing Record 35 of Set 12 | katsuura
# Processing Record 36 of Set 12 | tabou
# Processing Record 37 of Set 12 | north branch
# Processing Record 38 of Set 12 | fort nelson
# Processing Record 39 of Set 12 | nara
# Processing Record 40 of Set 12 | ossora
# Processing Record 41 of Set 12 | nakatsugawa
# Processing Record 42 of Set 12 | belaya gora
# Processing Record 43 of Set 12 | sambava
# Processing Record 44 of Set 12 | virden
# Processing Record 45 of Set 12 | oktyabrskiy
# Processing Record 46 of Set 12 | xichang
# Processing Record 47 of Set 12 | lar
# Processing Record 48 of Set 12 | miri
# Processing Record 49 of Set 12 | imeni poliny osipenko
# Processing Record 50 of Set 12 | bilma
# Processing Record 1 of Set 13 | sao francisco
# Processing Record 2 of Set 13 | tema
# Processing Record 3 of Set 13 | spiridonovka
# Processing Record 4 of Set 13 | sorong
# Processing Record 5 of Set 13 | mount isa
# Processing Record 6 of Set 13 | kangavar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Ushuaia -54.80  -68.30     35.60        94          40       18.34
# 1    Nacozari  25.34 -108.26     98.01        49          97       14.00
# 2        Soyo  -6.13   12.37     72.27        82           0        9.95
# 3     Qaanaaq  77.48  -69.36     47.61        58          86        3.80
# 4    Mercedes -34.65  -59.43     54.00        37          80        1.99
# 5       Bluff -46.60  168.33     39.00        83          82        3.00
# 6     Rikitea -23.12 -134.97     71.04        71           0       16.71
# 7    Hermanus -34.42   19.23     55.99        76           1       20.00
# 8  Port Blair  11.67   92.75     81.91        80         100       13.11
# 9      Albany  42.60  -73.97     90.00        36           8        9.15
#
#   Country                 Date  Snow  Rain Weather Description
# 0      AR  2020-07-12 21:12:13     0   0.0    scattered clouds
# 1      MX  2020-07-12 21:12:13     0   0.0     overcast clouds
# 2      AO  2020-07-12 21:12:13     0   0.0           clear sky
# 3      GL  2020-07-12 21:08:42     0   0.0     overcast clouds
# 4      AR  2020-07-12 21:12:14     0   0.0       broken clouds
# 5      NZ  2020-07-12 21:12:14     0   0.0       broken clouds
# 6      PF  2020-07-12 21:12:14     0   0.0           clear sky
# 7      ZA  2020-07-12 21:10:51     0   0.0           clear sky
# 8      IN  2020-07-12 21:12:14     0   0.0     overcast clouds
# 9      US  2020-07-12 21:07:15     0   0.0           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
